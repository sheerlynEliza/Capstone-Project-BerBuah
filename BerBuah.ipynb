# %%
! pip install -q kaggle
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-4408309f-8b07-45d5-9e23-1a303fa401bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4408309f-8b07-45d5-9e23-1a303fa401bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"sheerlyneliza","key":"6ba725a219ddba6ec9dc062adf2c64e3"}'}

# %%
# !mkdir ~/.kaggle

# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d ilyasaaffan/iwannafruits
# Out:
# ...
#  96% 97.0M/101M [00:01<00:00, 76.5MB/s]
# 100% 101M/101M [00:01<00:00, 66.3MB/s]

# %%
# !unzip /content/iwannafruits.zip
# Out:
# Archive:  /content/iwannafruits.zip
#   inflating: DATASET/test/Anggur/1.jpg
#   inflating: DATASET/test/Anggur/2.jpg
#   inflating: DATASET/test/Anggur/3.jpg
#   inflating: DATASET/test/Anggur/4.jpg
#   inflating: DATASET/test/Anggur/5.jpg
#   inflating: DATASET/test/Anggur/88_jpg.rf.3beda774ed0ae92c74aa24e235a11d47.jpg
#   inflating: DATASET/test/Anggur/90_jpg.rf.125720fae0cf1b5f909cb90275123127.jpg
#   inflating: DATASET/test/Anggur/92_jpg.rf.7d77798751fc2a9001c832e56c323172.jpg
#   inflating: DATASET/test/Anggur/94_jpg.rf.3513ba6cfcedd4d9ce686ce11252094d.jpg
#   inflating: DATASET/test/Anggur/96_jpg.rf.2249564ff537ddf8990066e7ba395e29.jpg
#   inflating: DATASET/test/Apel/23_jpg.rf.f98a2af4111f785c41403ba4547303c7.jpg
#   inflating: DATASET/test/Apel/25_jpg.rf.148254c22f391c2af5d8ee206e790213.jpg
#   inflating: DATASET/test/Apel/32_jpg.rf.b69f80b923530aad472c2d62bcece7d6.jpg
#   inflating: DATASET/test/Apel/33_jpg.rf.c6495e106c8c0d2ba97c471b7a4f1526.jpg
# ...

# %%
import os
import shutil

train_path = os.path.join('/content/DATASET/train')
valid_path = os.path.join('/content/DATASET/validation')

delete_path = ['Belimbing', 'Apel','Pisang']

for buah in delete_path:
  path = os.path.join(train_path, buah)
  shutil.rmtree(path)

for buah in delete_path:
  path = os.path.join(valid_path, buah)
  shutil.rmtree(path)

print(os.listdir(train_path))
print(os.listdir(valid_path))
# Out:
# ['Buah_Naga', 'Stroberi', 'Pepaya', 'Anggur', 'Kelapa', 'Nanas', 'Jeruk']
# ['Buah_Naga', 'Stroberi', 'Pepaya', 'Anggur', 'Kelapa', 'Nanas', 'Jeruk']

# %%
Anggur = os.path.join(train_path, 'Anggur')
Buah_Naga = os.path.join(train_path, 'Buah_Naga')
Jeruk = os.path.join(train_path, 'Jeruk')
Kelapa = os.path.join(train_path, 'Kelapa')
Nanas = os.path.join(train_path, 'Nanas')
Pepaya = os.path.join(train_path, 'Pepaya')
Stroberi = os.path.join(train_path, 'Stroberi')

# %%
import glob

total_image = len(list(glob.iglob("/content/DATASET/train//*/*.*", recursive=True)))
print("Total Image                    : ", total_image)

total_anggur = len(os.listdir(Anggur))
total_buah_naga = len(os.listdir(Buah_Naga))
total_jeruk = len(os.listdir(Jeruk))
total_kelapa = len(os.listdir(Kelapa))
total_nanas = len(os.listdir(Nanas))
total_pepaya = len(os.listdir(Pepaya))
total_stroberi = len(os.listdir(Stroberi))

print("Total Image Buah Anggur        : ", total_anggur)
print("Total Image Buah Naga          : ", total_buah_naga)
print("Total Image Buah Jeruk         : ", total_jeruk)
print("Total Image Buah Kelapa        : ", total_kelapa)
print("Total Image Buah Nanas         : ", total_nanas)
print("Total Image Buah Pepaya        : ", total_pepaya)
print("Total Image Buah Stroberi      : ", total_stroberi)
# Out:
# Total Image                    :  840
# Total Image Buah Anggur        :  120
# Total Image Buah Naga          :  120
# Total Image Buah Jeruk         :  120
# Total Image Buah Kelapa        :  120
# Total Image Buah Nanas         :  120
# Total Image Buah Pepaya        :  120
# Total Image Buah Stroberi      :  120

# %%
Anggur = os.path.join(valid_path, 'Anggur')
Buah_Naga = os.path.join(valid_path, 'Buah_Naga')
Jeruk = os.path.join(valid_path, 'Jeruk')
Kelapa = os.path.join(valid_path, 'Kelapa')
Nanas = os.path.join(valid_path, 'Nanas')
Pepaya = os.path.join(valid_path, 'Pepaya')
Stroberi = os.path.join(valid_path, 'Stroberi')

# %%
import glob

total_image = len(list(glob.iglob("/content/DATASET/validation//*/*.*", recursive=True)))
print("Total Image                    : ", total_image)

total_anggur = len(os.listdir(Anggur))
total_buah_naga = len(os.listdir(Buah_Naga))
total_jeruk = len(os.listdir(Jeruk))
total_kelapa = len(os.listdir(Kelapa))
total_nanas = len(os.listdir(Nanas))
total_pepaya = len(os.listdir(Pepaya))
total_stroberi = len(os.listdir(Stroberi))

print("Total Image Buah Anggur        : ", total_anggur)
print("Total Image Buah Naga          : ", total_buah_naga)
print("Total Image Buah Jeruk         : ", total_jeruk)
print("Total Image Buah Kelapa        : ", total_kelapa)
print("Total Image Buah Nanas         : ", total_nanas)
print("Total Image Buah Pepaya        : ", total_pepaya)
print("Total Image Buah Stroberi      : ", total_stroberi)
# Out:
# Total Image                    :  210
# Total Image Buah Anggur        :  30
# Total Image Buah Naga          :  30
# Total Image Buah Jeruk         :  30
# Total Image Buah Kelapa        :  30
# Total Image Buah Nanas         :  30
# Total Image Buah Pepaya        :  30
# Total Image Buah Stroberi      :  30

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout,Convolution2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.regularizers import l2
from tensorflow.keras.backend import clear_session
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import load_model
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
train_datagen = ImageDataGenerator(
     rescale=1./255,
    #shear_range=0.2,
    #rotation_range=30,
    fill_mode='reflect',
    zoom_range=0.2,
    #brightness_range=[0.8, 1.2],
    width_shift_range=0.2,
    height_shift_range=0.2,
    #horizontal_flip=True,
    #vertical_flip=True
)

validation_datagen = ImageDataGenerator(
     rescale=1./255
)

train_generator = train_datagen.flow_from_directory(
    directory=train_path,
    target_size=(224,224),
    class_mode='categorical',
    batch_size=10,
    color_mode='rgb'
)

validation_generator = validation_datagen.flow_from_directory(
    directory=valid_path,
    target_size=(224,224),
    class_mode='categorical',
    batch_size=20,
    color_mode='rgb'
)
# Out:
# Found 840 images belonging to 7 classes.
# Found 210 images belonging to 7 classes.

# %%
plt.figure(figsize=(16, 20))

for i in range(20):
    img, label = train_generator.next()
    plt.subplot(5, 4, i+1)
    plt.imshow(img[0])
    plt.axis('off')
    
plt.show()

# %%
varians_dict = train_generator.class_indices
print(varians_dict)
# Out:
# {'Anggur': 0, 'Buah_Naga': 1, 'Jeruk': 2, 'Kelapa': 3, 'Nanas': 4, 'Pepaya': 5, 'Stroberi': 6}

# %%
clear_session()

model = Sequential([
    Convolution2D(32, (5,5), activation = 'relu', input_shape= (224,224,3)),
    MaxPooling2D(2,2), 
    Convolution2D(32,(5,5), activation= 'relu'),
    MaxPooling2D(2,2),
    Convolution2D(64,(5,5), activation= 'relu'),
    MaxPooling2D(2,2),
    Convolution2D(64,(5,5), activation= 'relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(128, activation= 'relu'),
    Dropout(0.2),
    Dense(64, activation= 'relu',kernel_regularizer=l2(0.001)),
    Dropout(0.2),
    Dense(7, activation= 'softmax')
])

model.compile(
    optimizer=Adam(learning_rate=1e-4), #0.0001
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 220, 220, 32)      2432
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 106, 106, 32)      25632
#
#  max_pooling2d_1 (MaxPooling  (None, 53, 53, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 49, 49, 64)        51264
#
#  max_pooling2d_2 (MaxPooling  (None, 24, 24, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 64)        102464
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 128)               819328
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
# ...

# %%
h = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=35)
# Out:
# Epoch 1/35
# 84/84 [==============================] - 36s 242ms/step - loss: 1.9556 - accuracy: 0.2119 - val_loss: 1.5727 - val_accuracy: 0.4048
# Epoch 2/35
# 84/84 [==============================] - 15s 184ms/step - loss: 1.5234 - accuracy: 0.3929 - val_loss: 1.0489 - val_accuracy: 0.6571
# Epoch 3/35
# 84/84 [==============================] - 15s 181ms/step - loss: 1.1161 - accuracy: 0.5798 - val_loss: 0.6648 - val_accuracy: 0.7714
# Epoch 4/35
# 84/84 [==============================] - 16s 191ms/step - loss: 0.9239 - accuracy: 0.6548 - val_loss: 0.5448 - val_accuracy: 0.8048
# Epoch 5/35
# 84/84 [==============================] - 16s 186ms/step - loss: 0.7771 - accuracy: 0.7143 - val_loss: 0.6436 - val_accuracy: 0.7571
# Epoch 6/35
# 84/84 [==============================] - 15s 179ms/step - loss: 0.7672 - accuracy: 0.7107 - val_loss: 0.5139 - val_accuracy: 0.8476
# Epoch 7/35
# ...

# %%
train_acc = h.history['accuracy']
train_loss = h.history['loss']
val_acc = h.history['val_accuracy']
val_loss = h.history['val_loss']

plt.figure(figsize=(16,6))
plt.subplot(1, 2, 1)
plt.title('Accuracy Curve')
plt.plot(train_acc, label='Training')
plt.plot(val_acc, label='Validation')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.subplot(1, 2, 2)
plt.title('Loss Curve')
plt.plot(train_loss, label='Training')
plt.plot(val_loss, label='Validation')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.show()

# %%
test_dir = '/content/DATASET/test'

for varian in varians_dict.keys():
    images_list = os.listdir(os.path.join(test_dir, varian))    
#     plt.figure(figsize=(16, 20))

    correct_count = 0
    count = 0

    for idx, image in enumerate(images_list):
        img_path = f'/content/DATASET/test/{varian}/{image}'
        img = load_img(img_path, target_size=(224, 224))

        img_array = img_to_array(img)
        img_array = tf.expand_dims(img_array, 0)

        varians_list = list(varians_dict.keys())
        prediction = model(img_array)
        pred_idx = np.argmax(prediction)
        pred_varian = varians_list[pred_idx]
        pred_confidence = prediction[0][pred_idx] * 100

        if pred_varian == varian:
            correct_count += 1
            count +=1
        elif pred_varian != varian:
            count +=1

#         plt.subplot(5, 4, idx+1)
#         plt.title(f'Actual: {motive}\nPrediction: {pred_motive} {pred_confidence:.2f}%')
#         plt.imshow(img)
#         plt.axis('off')
    
    print(f'{varian} Predictions --> {correct_count}/{count} correct')
# plt.show()
# Out:
# Anggur Predictions --> 10/10 correct
# Buah_Naga Predictions --> 7/10 correct
# Jeruk Predictions --> 9/10 correct
# Kelapa Predictions --> 10/10 correct
# Nanas Predictions --> 9/10 correct
# Pepaya Predictions --> 10/10 correct
# Stroberi Predictions --> 10/10 correct

# %%
model_save_path = "saved_model/11_varians"
tf.saved_model.save(model, model_save_path)
# Out:
# INFO:tensorflow:Assets written to: saved_model/11_varians/assets

# %%
tf.keras.models.save_model(model, 'Fruits.h5')

# %%
# Convert the model
converter = tf.lite.TFLiteConverter.from_saved_model(model_save_path) # path to the SavedModel directory
tflite_model = converter.convert()
# Out:
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded

# %%
# Save the model.
path = '/content'
os.chdir(path)
# %cd '/content'
# !rm -rf '/content/model_tflite'
# !mkdir '/content/model_tflite'
# %cd '/content/model_tflite'
with open('11_varians.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# /content
# /content/model_tflite

# %%
for varian in varians_list:
    print(varian)
# Out:
# Anggur
# Buah_Naga
# Jeruk
# Kelapa
# Nanas
# Pepaya
# Stroberi
